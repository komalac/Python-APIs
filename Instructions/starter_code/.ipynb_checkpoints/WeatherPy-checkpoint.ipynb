# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
cities = []

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# cities = ["Paris", "London", "Oslo", "Beijing"]
# Out:
# ['chivay',
#  'bethel',
#  'qaanaaq',
#  'urgut',
#  'carnarvon',
#  'puerto ayora',
#  'hermanus',
#  'new norfolk',
#  'lebu',
#  'punta arenas',
#  'ushuaia',
#  'laguna',
#  'ayame',
#  'sentyabrskiy',
#  'port lincoln',
#  'sorong',
#  'souillac',
#  'busselton',
#  'biak',
#  'dingli',
#  'namibe',
#  'victoria',
#  'amga',
#  'albany',
#  'yellowknife',
#  'katsuura',
#  'lolua',
#  'taolanaro',
#  'bilibino',
#  'sobolevo',
#  'goderich',
#  'mataura',
#  'bilma',
#  'tazovskiy',
#  'taoudenni',
#  'mayo',
#  'kathmandu',
#  'illoqqortoormiut',
#  'bredasdorp',
#  'hobart',
#  'ellsworth',
#  'ponta do sol',
#  'fairview',
#  'vaini',
#  'srednekolymsk',
#  'barrow',
#  'tombouctou',
#  'nakama',
#  'swan hill',
#  'avera',
#  'rikitea',
#  'franklin park',
#  'hovd',
#  'pacific grove',
#  'sokoni',
#  'ostrovnoy',
#  'reyes',
#  'bluff',
#  'halalo',
#  'pisco',
#  'maceio',
#  'hofn',
#  'kropotkin',
#  'cherskiy',
#  'codrington',
#  'isabela',
#  'atuona',
#  'kapaa',
#  'belushya guba',
#  'tuktoyaktuk',
#  'luxeuil-les-bains',
#  'aklavik',
#  'sitka',
#  'sao joao da barra',
#  'kavieng',
#  'igrim',
#  'mahebourg',
#  'waingapu',
#  'kununurra',
#  'vila',
#  'hasaki',
#  'nanortalik',
#  'pingdingshan',
#  'solwezi',
#  'panzhihua',
#  'jiddah',
#  'komsomolskiy',
#  'pleasanton',
#  'fortuna',
#  'fevralsk',
#  'high level',
#  'lucea',
#  'kutum',
#  'geraldton',
#  'polunochnoye',
#  'sabha',
#  'suluova',
#  'tupik',
#  'chokurdakh',
#  'grand gaube',
#  'coquimbo',
#  'saskylakh',
#  'airai',
#  'khatanga',
#  'gorontalo',
#  'kaitangata',
#  'sidi qasim',
#  'castro',
#  'kahului',
#  'scottsbluff',
#  'talnakh',
#  'severo-kurilsk',
#  'jamestown',
#  'toora-khem',
#  'tynda',
#  'esperance',
#  'nizhneyansk',
#  'kawalu',
#  'camacha',
#  'margate',
#  'bubaque',
#  'kloulklubed',
#  'karakol',
#  'dingle',
#  'gondanglegi',
#  'gushikawa',
#  'kodiak',
#  'hilo',
#  'okhotsk',
#  'birao',
#  'bokspits',
#  'zaragoza',
#  'batsfjord',
#  'lavrentiya',
#  'pevek',
#  'inhambane',
#  'karauzyak',
#  'cape town',
#  'saldanha',
#  'saiha',
#  'jeremie',
#  'mazagao',
#  'constantine',
#  'hopewell',
#  'ribeira grande',
#  'dongsheng',
#  'karachi',
#  'juegang',
#  'luganville',
#  'arraial do cabo',
#  'ambilobe',
#  'cabedelo',
#  'dikson',
#  'east london',
#  'aketi',
#  'port alfred',
#  'lexington',
#  'ormara',
#  'buzmeyin',
#  'dakar',
#  'yumen',
#  'mount isa',
#  'rio grande',
#  'faya',
#  'gazanjyk',
#  'longyearbyen',
#  'nuuk',
#  'zhigansk',
#  'korla',
#  'beringovskiy',
#  'kamenka',
#  'saint-georges',
#  'camapua',
#  'khandyga',
#  'leutkirch',
#  'tortoli',
#  'burdinne',
#  'itaituba',
#  'cumana',
#  'sao gabriel da cachoeira',
#  'college',
#  'port-gentil',
#  'kalmunai',
#  'takoradi',
#  'tottori',
#  'boende',
#  'faanui',
#  'hithadhoo',
#  'nadym',
#  'caravelas',
#  'poum',
#  'kiunga',
#  'mount gambier',
#  'broome',
#  'salalah',
#  'halifax',
#  'provideniya',
#  'conceicao do araguaia',
#  'kuloy',
#  'shizunai',
#  'nioki',
#  'vaitupu',
#  'williston',
#  'paamiut',
#  'hashtrud',
#  'mao',
#  'grindavik',
#  'la asuncion',
#  'georgetown',
#  'vanimo',
#  'butaritari',
#  'bograd',
#  'alice springs',
#  'upernavik',
#  'raudeberg',
#  'agirish',
#  'union de san antonio',
#  'ancud',
#  'rio gallegos',
#  'barbar',
#  'keti bandar',
#  'charters towers',
#  'northam',
#  'vyazemskiy',
#  'malbug',
#  'vao',
#  'mar del plata',
#  'ixtapa',
#  'thompson',
#  'krasnyy chikoy',
#  'necochea',
#  'sidi bu zayd',
#  'naze',
#  'barentsburg',
#  'naranjal',
#  'burriana',
#  'torrington',
#  'monreal',
#  'xichang',
#  'lompoc',
#  'tiksi',
#  'gat',
#  'manggar',
#  'qaqortoq',
#  'sfantu gheorghe',
#  'san rafael del sur',
#  'vite',
#  'hit',
#  'palabuhanratu',
#  'linxia',
#  'pravokubanskiy',
#  'chuy',
#  'tabiauea',
#  'nantucket',
#  'ilulissat',
#  'clyde river',
#  'hamilton',
#  'vestmannaeyjar',
#  'kundiawa',
#  'rocha',
#  'longjiang',
#  'cidreira',
#  'san jose',
#  'naples',
#  'vila franca do campo',
#  'tekirdag',
#  'mys shmidta',
#  'mareeba',
#  'sungai siput utara',
#  'namatanai',
#  'torbay',
#  'haifa',
#  'kazalinsk',
#  'tuatapere',
#  'avarua',
#  'harboore',
#  'luderitz',
#  'uberlingen',
#  'mwinilunga',
#  'saint stephen',
#  'huaraz',
#  'amderma',
#  'alofi',
#  'tessalit',
#  'babanusah',
#  'tasiilaq',
#  'lewiston',
#  'mugur-aksy',
#  'prince rupert',
#  'mundo nuevo',
#  'mahibadhoo',
#  'broken hill',
#  'attawapiskat',
#  'san policarpo',
#  'treinta y tres',
#  'constitucion',
#  'russell',
#  'saleaula',
#  'tumannyy',
#  'grand river south east',
#  'umm durman',
#  'nikolskoye',
#  'basco',
#  'smoky lake',
#  'jiuquan',
#  'kalachinsk',
#  'wanxian',
#  'wajima',
#  'bambous virieux',
#  'bull savanna',
#  'hami',
#  'baykalsk',
#  'kotido',
#  'rawson',
#  'pasni',
#  'sao filipe',
#  'orcopampa',
#  'villa bruzual',
#  'sokoto',
#  'bulgan',
#  'isangel',
#  'ponta delgada',
#  'balikpapan',
#  'kudahuvadhoo',
#  'jalingo',
#  'deputatskiy',
#  'guamuchil',
#  'nebbi',
#  'demirci',
#  'saint-philippe',
#  'marcona',
#  'verkhoyansk',
#  'tabou',
#  'qasigiannguit',
#  'manokwari',
#  'farafenni',
#  'yabrud',
#  'north bend',
#  'tsihombe',
#  'xinmin',
#  'kamenskoye',
#  'aykhal',
#  'guerrero negro',
#  'victor harbor',
#  'leningradskiy',
#  'acajutla',
#  'touros',
#  'pangkalanbuun',
#  'jinchang',
#  'saint george',
#  'lusambo',
#  'kruisfontein',
#  'barcelos',
#  'el tigre',
#  'palmer',
#  'hualmay',
#  'chara',
#  'shingu',
#  'karpathos',
#  'palmas',
#  'capitao poco',
#  'zhangjiakou',
#  'praya',
#  'honningsvag',
#  'antalaha',
#  'aksu',
#  'bengkulu',
#  'port elizabeth',
#  'nouadhibou',
#  'rondonopolis',
#  'fayaoue',
#  'norman wells',
#  'montrose',
#  'carutapera',
#  'lima',
#  'mahon',
#  'zabol',
#  'borujan',
#  'port hedland',
#  'casale monferrato',
#  'taitung',
#  'chavantes',
#  'kilifi',
#  'marzuq',
#  'kysyl-syr',
#  'cabra',
#  'honiara',
#  'yakeshi',
#  'narsaq',
#  'toliary',
#  'ploemeur',
#  'sinnar',
#  'mayor pablo lagerenza',
#  'mwandiga',
#  'bombay',
#  'walvis bay',
#  'west bay',
#  'tuxpan',
#  'coihaique',
#  'ust-omchug',
#  'seoul',
#  'omboue',
#  'aguimes',
#  'kayerkan',
#  'anloga',
#  'sayyan',
#  'bambanglipuro',
#  'vardo',
#  'tambun',
#  'zambezi',
#  'aba',
#  'havoysund',
#  'kaoma',
#  'iskateley',
#  'ahipara',
#  'rexburg',
#  'neepawa',
#  'nome',
#  'smolenka',
#  'atar',
#  'quedlinburg',
#  'denau',
#  'christchurch',
#  'kavaratti',
#  'westport',
#  'mersing',
#  'labuhan',
#  'burnie',
#  'dukhovnitskoye',
#  'pierre',
#  'jacareacanga',
#  'iqaluit',
#  'chalus',
#  'sechura',
#  'laurel',
#  'kantemirovka',
#  'krasnyye baki',
#  'armacao dos buzios',
#  'yar-sale',
#  'cairns',
#  'bereda',
#  'buchanan',
#  'izhma',
#  'ceyhan',
#  'ca mau',
#  'am timan',
#  'marshfield',
#  'lagoa',
#  'waipawa',
#  'svetlaya',
#  'swellendam',
#  'quatre cocos',
#  'batamshinskiy',
#  'evensk',
#  'hargeysa',
#  'cheremshan',
#  'la tuque',
#  'buckeye',
#  'junin',
#  'saint-francois',
#  'ati',
#  'kerouane',
#  'chapais',
#  'kemijarvi',
#  'borba',
#  'ketchikan',
#  'bobo dioulasso',
#  'naolinco',
#  'aksarka',
#  'solovetskiy',
#  'umzimvubu',
#  'lingao',
#  'kumluca',
#  'letchworth',
#  'maloshuyka',
#  'lodja',
#  'okha',
#  'haibowan',
#  'kalaleh',
#  'hambantota',
#  'ulaanbaatar',
#  'abu kamal',
#  'acapulco',
#  'kieta',
#  'ngaoundere',
#  'coahuayana',
#  'san juan pueblo',
#  'sangar',
#  'sal rei',
#  'praia',
#  'andarab',
#  'jalu',
#  'shahpur',
#  'torbeyevo',
#  'fairbanks',
#  'horadiz',
#  'asekeyevo',
#  'san cristobal',
#  'bairiki',
#  'jacksonville',
#  'huarmey',
#  'neka',
#  'asau',
#  'kenai',
#  'arlit',
#  'bathsheba',
#  'bolshaya dzhalga',
#  'meulaboh',
#  'sug-aksy',
#  'piacabucu',
#  'karratha',
#  'kaupanger',
#  'along',
#  'port hardy',
#  'kati',
#  'wajir',
#  'yerbogachen',
#  'husavik',
#  'jurm',
#  'bulawayo',
#  'eydhafushi',
#  'mitsamiouli',
#  'oxford',
#  'samusu',
#  'ijaki',
#  'alugan',
#  'nogent-le-rotrou',
#  'guapiles',
#  'eyl',
#  'taraz',
#  'sandwick',
#  'utiroa',
#  'marienburg',
#  'harbour breton',
#  'garut',
#  'soyo',
#  'hat yai',
#  'bembibre',
#  'pangnirtung',
#  'udachnyy',
#  'bryan',
#  'bima',
#  'saint-augustin',
#  'port-cartier',
#  'kota belud',
#  'luzilandia',
#  'axim',
#  'dothan',
#  'zyryanka',
#  'shenjiamen',
#  'daru',
#  'svetlyy',
#  'motygino',
#  'ilheus',
#  'kuche',
#  'hervey bay',
#  'kedgwick',
#  'champerico',
#  'stavern',
#  'cabo san lucas',
#  'vostok',
#  'itarema',
#  'tatawin',
#  'kintampo',
#  'qui nhon',
#  'yenagoa',
#  'foca',
#  'thunder bay',
#  'pisz',
#  'ridgecrest',
#  'cazaje',
#  'ushtobe',
#  'little current',
#  'yeppoon',
#  'yamoussoukro',
#  'kyren',
#  'yuancheng',
#  'lushunkou',
#  'ust-tsilma',
#  'lovington',
#  'marsh harbour',
#  'klaksvik',
#  'thanh hoa',
#  'marsa matruh',
#  'jos',
#  'adrar',
#  'atambua',
#  'yulara',
#  'troy',
#  'san patricio',
#  'tura',
#  'langsa',
#  'thinadhoo',
#  'natal',
#  'gualaquiza',
#  'homer',
#  'ensley',
#  'kokopo',
#  'todos santos',
#  'craig',
#  'iberia',
#  'otradnoye',
#  'emerald',
#  'samarai',
#  'chimbote',
#  'lahij',
#  'santa cruz de la palma',
#  'bud',
#  'kidal',
#  'santa rosa',
#  'kobryn',
#  'borgarnes',
#  'chifeng',
#  'beyneu',
#  'abu dhabi',
#  'mumford',
#  'semypolky',
#  'chateauroux',
#  'havre-saint-pierre',
#  'ocampo',
#  'mocuba',
#  'payo',
#  'praia da vitoria']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# Creating empty list
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
MaxTemp = []
WindSpeed = []

#looping through all cities
for city in cities:
    # Build query URL
    query_url = url + "appid=" + api_key + "&q=" + city
    # Query API
    response = requests.get(query_url).json()
    response
    # adding the valid response to the lists inside try block, to avoid exceptions when the request didn't find any city
    try:
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        MaxTemp.append(response['main']['temp_max'])
        WindSpeed.append(response['wind']['speed'])
    # Except block will print a message for the cities that did not receive any response
    except:
        print("City does not exist")
# Out:
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Converting the unix dateformat into readble format
ConvDate = [datetime.datetime.utcfromtimestamp(int(i)).strftime('%Y-%m-%d %H:%M:%S') for i in Date]
ConvDate
# Out:
# ['2018-10-09 00:38:21',
#  '2018-10-08 23:53:00',
#  '2018-10-09 00:45:46',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:45:47',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:45:48',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-08 23:41:00',
#  '2018-10-09 00:38:25',
#  '2018-10-09 00:45:50',
#  '2018-10-09 00:37:36',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:45:52',
#  '2018-10-09 00:45:52',
#  '2018-10-08 23:45:00',
#  '2018-10-09 00:45:53',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:45:53',
#  '2018-10-08 23:54:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:36:13',
#  '2018-10-09 00:38:31',
#  '2018-10-09 00:38:31',
#  '2018-10-09 00:45:57',
#  '2018-10-09 00:38:32',
#  '2018-10-09 00:43:18',
#  '2018-10-09 00:38:33',
#  '2018-10-09 00:00:00',
#  '2018-10-08 23:50:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:30:00',
#  '2018-10-08 23:56:00',
#  '2018-10-09 00:46:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:46:01',
#  '2018-10-09 00:46:01',
#  '2018-10-09 00:46:02',
#  '2018-10-09 00:38:38',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:38:38',
#  '2018-10-09 00:05:00',
#  '2018-10-09 00:46:03',
#  '2018-10-09 00:15:00',
#  '2018-10-09 00:20:00',
#  '2018-10-08 23:55:00',
#  '2018-10-09 00:38:40',
#  '2018-10-09 00:46:05',
#  '2018-10-09 00:38:41',
#  '2018-10-09 00:46:06',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:46:07',
#  '2018-10-09 00:38:43',
#  '2018-10-09 00:46:08',
#  '2018-10-09 00:46:08',
#  '2018-10-09 00:38:44',
#  '2018-10-09 00:40:57',
#  '2018-10-08 23:56:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:46:11',
#  '2018-10-09 00:46:12',
#  '2018-10-09 00:46:12',
#  '2018-10-09 00:38:47',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:38:48',
#  '2018-10-09 00:30:00',
#  '2018-10-08 23:50:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:46:15',
#  '2018-10-09 00:38:50',
#  '2018-10-09 00:38:50',
#  '2018-10-09 00:38:51',
#  '2018-10-09 00:38:51',
#  '2018-10-08 23:58:00',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:38:53',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:38:54',
#  '2018-10-09 00:38:54',
#  '2018-10-08 23:50:00',
#  '2018-10-09 00:38:55',
#  '2018-10-09 00:45:19',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00

#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:32',
#  '2018-10-09 00:00:00',
#  '2018-10-08 23:50:00',
#  '2018-10-09 00:20:00',
#  '2018-10-09 00:41:34',
#  '2018-10-09 00:41:34',
#  '2018-10-09 00:41:35',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:48:49',
#  '2018-10-09 00:39:08',
#  '2018-10-09 00:15:00',
#  '2018-10-09 00:41:37',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:38',
#  '2018-10-09 00:47:15',
#  '2018-10-08 23:58:00',
#  '2018-10-09 00:41:39',
#  '2018-10-09 00:41:40',
#  '2018-10-09 00:41:40',
#  '2018-10-09 00:41:41',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:42',
#  '2018-10-09 00:41:42',
#  '2018-10-08 23:46:00',
#  '2018-10-09 00:20:00',
#  '2018-10-08 23:47:00',
#  '2018-10-09 00:41:43',
#  '2018-10-09 00:48:57',
#  '2018-10-09 00:41:44',
#  '2018-10-09 00:41:45',
#  '2018-10-09 00:20:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:18',
#  '2018-10-08 23:56:00',
#  '2018-10-09 00:41:47',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:48',
#  '2018-10-09 00:41:48',
#  '2018-10-09 00:41:49',
#  '2018-10-09 00:15:00',
#  '2018-10-09 00:49:03',
#  '2018-10-09 00:20:00',
#  '2018-10-09 00:41:51',
#  '2018-10-09 00:41:51',
#  '2018-10-09 00:41:52',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:52',
#  '2018-10-09 00:00:00',
#  '2018-10-08 23:54:00',
#  '2018-10-09 00:41:53',
#  '2018-10-09 00:41:54',
#  '2018-10-09 00:41:54',
#  '2018-10-09 00:41:55',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:55',
#  '2018-10-08 23:53:00',
#  '2018-10-08 23:55:00',
#  '2018-10-09 00:41:57',
#  '2018-10-08 23:47:00',
#  '2018-10-09 00:13:00',
#  '2018-10-09 00:39:03',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:41:59',
#  '2018-10-09 00:41:59',
#  '2018-10-09 00:41:59',
#  '2018-10-09 00:40:55',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:20:00',
#  '2018-10-09 00:42:02',
#  '2018-10-09 00:42:03',
#  '2018-10-09 00:42:03',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:49:14',
#  '2018-10-09 00:42:04',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:42:05',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:30:00',
#  '2018-10-09 00:00:00',
#  '2018-10-09 00:42:06',
#  '2018-10-09 00:42:07',
#  '2018-10-09 00:42:07',
#  '2018-10-09 00:00:00']

# %%
# writing all lists to a dictionary
CityWeather_dict = {
    "Cloudiness":Cloudiness,
    "Country":Country,
    "Date":ConvDate,
    "Humidity":Humidity,
    "Lat":Lat,
    "Lng":Lng,
    "MaxTemp":MaxTemp,
    "WindSpeed":WindSpeed
}

# %%
# Creating a dataframe out ot the dictionary created above
CityWeatherData_df = pd.DataFrame(CityWeather_dict)
CityWeatherData_df
# Out:
#      Cloudiness Country                 Date  Humidity    Lat     Lng  \
# 0             8      PE  2018-10-09 00:38:21        61 -15.64  -71.60
# 1             1      US  2018-10-08 23:53:00        71  60.79 -161.76
# 2            12      GL  2018-10-09 00:45:46       100  77.48  -69.36
# 3            75      UZ  2018-10-09 00:00:00        87  39.41   67.25
# 4             0      ZA  2018-10-09 00:45:47        23 -30.97   22.13
# 5             0      EC  2018-10-09 00:00:00        73  -0.74  -90.35
# 559          90      FR  2018-10-09 00:30:00       100  43.72    0.65
# 560          75      CA  2018-10-09 00:00:00        80  50.23  -63.60
# 561          92      PH  2018-10-09 00:42:06       100  13.56  123.37
# 562          56      MZ  2018-10-09 00:42:07        98 -16.84   36.99
# 563           8      ID  2018-10-09 00:42:07        90  -3.75  103.64
# 564          20      PT  2018-10-09 00:00:00        83  38.73  -27.07
#
#      MaxTemp  WindSpeed
# 0    276.356       1.61
# 1    284.250       5.10
# 2    264.306       4.66
# 3    280.150       2.10
# 4    289.506       3.21
# 5    296.150       6.70
# 6    287.356       0.86
# 7    284.150      10.80
# 8    287.150       1.50
# 9    277.150       3.10
# 10   280.150       8.20
# 11   299.150       3.10
# 12   298.056       3.06
# 13   287.756       8.06
# 14   300.356       2.66
# 15   285.150       1.81
# 16   289.406       7.36
# 17   299.556       2.01
# 18   293.150       3.31
# 19   293.056       3.66
# 20   303.150       1.00
# 21   270.656       1.61
# 22   289.850       4.10
# 23   274.150       1.41
# 24   293.150       1.50
# 25   270.906       1.41
# 26   272.406       1.31
# 27   294.906       6.66
# 28   287.406       6.61
# 29   294.606       1.31
# ..       ...        ...
# 535  299.150       5.70
# 536  291.706       0.91
# 537  283.750       1.50
# 538  300.950       2.10
# 539  298.506       3.61
# 540  302.150       5.10
# 541  278.750       1.31
# 542  296.906       1.16
# 543  280.150       3.00
# 544  298.556       4.76
# 545  298.606       3.91
# 546  290.656       2.96
# 547  287.706       1.16
# 548  299.150       5.10
# 549  282.150       2.60
# 550  296.756       2.51
# 551  291.206       2.66
# 552  275.306       1.31
# 553  275.150       4.10
# 554  274.706       3.06
# 555  277.156       3.66
# 556  302.150       1.50
# 557  297.406       2.66
# 558  281.150       6.00
# 559  286.150       1.00
# 560  277.150       5.10
# 561  298.956       1.76
# 562  291.656       2.06
# 563  296.656       1.81
# 564  294.150       5.91
#
# [565 rows x 8 columns]

# %%
# writing the dataframe into a csv
CityWeatherData_df.to_csv('CityData.csv')

# %%
# Getting current date to mention with the title
CurrDate = datetime.datetime.today().strftime('%m-%d-%Y')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(CityWeatherData_df["Lat"], CityWeatherData_df["MaxTemp"], marker="o", alpha=1)

# Incorporate the other graph properties
plt.title(f"Latitude Vs Temprature Plot - {CurrDate}")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(CityWeatherData_df["Lat"], CityWeatherData_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title(f"Latitude Vs Humidity Plot - {CurrDate}")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(CityWeatherData_df["Lat"], CityWeatherData_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title(f"Latitude Vs Cloudiness Plot - {CurrDate}")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(CityWeatherData_df["Lat"], CityWeatherData_df["WindSpeed"], marker="o")

# Incorporate the other graph properties
plt.title(f"Latitude Vs WindSpeed Plot - {CurrDate}")
plt.ylabel("WindSpeed")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()
